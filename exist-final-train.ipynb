# %%
pip install transformers datasets evaluate pysentimiento
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.39.3)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.18.0)
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Collecting pysentimiento
#   Downloading pysentimiento-0.7.3-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: accelerate>=0.27.2 in /opt/conda/lib/python3.10/site-packages (from pysentimiento) (0.29.3)
# Requirement already satisfied: emoji>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from pysentimiento) (2.11.0)
# Requirement already satisfied: spacy>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from pysentimiento) (3.7.3)
# Requirement already satisfied: torch!=2.0.1,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pysentimiento) (2.1.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->pysentimiento) (5.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (2.5.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (69.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy>=3.5.0->pysentimiento) (3.3.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.5.0->pysentimiento) (2.14.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.5.0->pysentimiento) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.5.0->pysentimiento) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy>=3.5.0->pysentimiento) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.5.0->pysentimiento) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy>=3.5.0->pysentimiento) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch!=2.0.1,>=2.0.0->pysentimiento) (1.3.0)
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.8 MB/s eta 0:00:00
# Downloading pysentimiento-0.7.3-py3-none-any.whl (39 kB)
# Installing collected packages: evaluate, pysentimiento
# Successfully installed evaluate-0.4.2 pysentimiento-0.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
from pysentimiento.preprocessing import preprocess_tweet


def simple_preprocess(text):
    """
    Preprocesses a single tweet string to replace user handles and URLs.
    """
    URL_RE = re.compile(r"https?:\/\/[\w\.\/\?\=\d%_:/-]+")
    HANDLE_RE = re.compile(r"@\w+")
    text = HANDLE_RE.sub("@USER", text)
    text = URL_RE.sub("HTTPURL", text)
    return text

def tweet_preprocessor_spanish(text):
    """
    imported from pysentimiento
    does the following:
    1. changes to @usario
    2. shortens characters repetitions to 3 (can be changed to two or more)
    3. converts emojis to text type of need
    4. normalises laughter expressions
    5. handles hashtags -- removes the #
    """
    return preprocess_tweet(text, lang="es", shorten=3)

def tweet_preprocessor_english(text):
    """
    imported from pysentimiento
    does the following:
    1. changes to @usario
    2. shortens characters repetitions to 3 (can be changed to two or more)
    3. converts emojis to text type of need
    4. normalises laughter expressions
    5. handles hashtags -- removes the #
    """
    return preprocess_tweet(text, lang="en", shorten=3)

# %%
import numpy as np
import pandas as pd
Train = pd.read_csv('/kaggle/input/existv1/balanced_train.csv')
Val = pd.read_csv('/kaggle/input/existv1/balanced_val.csv')

# %%
Train = Train[['tweet', 'task2_hard_labels']]
Val = Val[['tweet', 'task2_hard_labels']]

# %%
Train = Train[Train['task2_hard_labels'] != 'UND']
Val = Val[Val['task2_hard_labels'] != 'UND']

# %%
Train['tweet'] = Train['tweet'].apply(simple_preprocess)
Train['tweet'] = Train['tweet'].apply(tweet_preprocessor_spanish)
Train['tweet'] = Train['tweet'].apply(tweet_preprocessor_english)
Val['tweet'] = Val['tweet'].apply(simple_preprocess)
Val['tweet'] = Val['tweet'].apply(tweet_preprocessor_spanish)
Val['tweet'] = Val['tweet'].apply(tweet_preprocessor_english)

# %%
Train.rename(columns={'task2_hard_labels': 'label'}, inplace=True)
Val.rename(columns={'task2_hard_labels': 'label'}, inplace=True)

# %%
Train
# Out:
#                                                    tweet        label
# 0      El primer tuit que escribí esta mañana fue en ...     REPORTED
# 1      @USER TiranicidioYa @USER AlertaNews24 Hey más...  JUDGEMENTAL
# 2      Can men stop threatening to spank women wtf. G...     REPORTED
# 3      / annabeth está para romper el estereotipo de ...  JUDGEMENTAL
# 4      @USER proctor_jason Funny enough the free woma...     REPORTED
# ...                                                  ...          ...
# 15444  Cómo quieren que mejoremos cómo sociedad si no...            -
# 15445  emoji tijeras emoji "Decidieron arbitrariament...            -
# 15446  Witch raises wind to break up enemys lumber po...            -
# 15447  @USER TheEAC37 @USER MyGrindelwald @USER Disne...  JUDGEMENTAL
# 15448  It looks like the only vocabulary you enjoy em...  JUDGEMENTAL
#
# [15449 rows x 2 columns]

# %%
def factorize_column(df, column_name):
    """
    Factorizes a specified column of a pandas DataFrame.

    Parameters:
        df (pd.DataFrame): The DataFrame containing the column to be factorized.
        column_name (str): The name of the column to factorize.

    Returns:
        pd.DataFrame: A DataFrame with the specified column factorized.
        pd.Series: The array containing the labels corresponding to the factorized codes.
    """
    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")

    # Factorize the column
    codes, uniques = pd.factorize(df[column_name])

    # Replace the original column with the encoded data
    df[column_name] = codes

    # Return the modified DataFrame and the unique labels
    return df, uniques

# %%
Train, unique = factorize_column(Train, 'label')
unique
# Out:
# Index(['REPORTED', 'JUDGEMENTAL', 'DIRECT', '-'], dtype='object')

# %%
Train.head(5)
# Out:
#                                                tweet  label
# 0  El primer tuit que escribí esta mañana fue en ...      0
# 1  @USER TiranicidioYa @USER AlertaNews24 Hey más...      1
# 2  Can men stop threatening to spank women wtf. G...      0
# 3  / annabeth está para romper el estereotipo de ...      1
# 4  @USER proctor_jason Funny enough the free woma...      0

# %%
# Creating the id2label dictionary
id2label = {idx: label for idx, label in enumerate(unique)}
# Creating the label2id dictionary
label2id = {label: idx for idx, label in enumerate(unique)}

# %%
def factorize_column_custom(df, column_name, label2id):
    """
    Factorizes a specified column of a pandas DataFrame according to a given label2id dictionary.

    Parameters:
        df (pd.DataFrame): The DataFrame containing the column to be factorized.
        column_name (str): The name of the column to factorize.
        label2id (dict): Dictionary mapping labels to IDs.

    Returns:
        pd.DataFrame: A DataFrame with the specified column factorized.
        pd.Index: The array containing the labels in the order used for factorization.
    """
    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")
    
    # Apply the mapping from label2id to the column
    df[column_name] = df[column_name].map(label2id).fillna(-1)  # Use -1 for any unknown categories

    # Create an Index from label2id for returning, sorted by the ID values
    sorted_labels = sorted(label2id.items(), key=lambda x: x[1])
    labels_index = pd.Index([label for label, _ in sorted_labels], dtype='object')

    # Return the modified DataFrame and the sorted labels as an Index
    return df, labels_index

# %%
Val, vunique = factorize_column_custom(Val, 'label', label2id)
vunique
# Out:
# Index(['REPORTED', 'JUDGEMENTAL', 'DIRECT', '-'], dtype='object')

# %%
Val.head(5)
# Out:
#                                                tweet  label
# 0  Acompáñenme por este viaje de olvido de tu coa...      1
# 1  El estigma es algo que nos atraviesa a todas l...      0
# 2  Most married women don't know the price of alc...      2
# 3  𝐇𝐚𝐩𝐩𝐲 𝐖𝐨𝐦𝐞𝐧'𝐬 𝐃𝐚𝐲 to all the lovely ladies  em...      3
# 4  @USER @USER FP trabajando por un futuro de igu...      3

# %%
from datasets import Dataset, DatasetDict

# Creating instances of CustomDataset for train and test sets
train_dataset = Dataset.from_pandas(Train)
val_dataset = Dataset.from_pandas(Val)

# Organizing the datasets into a dictionary-like structure
dataset_dict = DatasetDict({
    "train": train_dataset,
    "val": val_dataset
})


dataset_dict["train"][0]
# Out:
# {'tweet': 'El primer tuit que escribí esta mañana fue en apoyo a @USER vtrivella. Vi el video donde ella denuncia el acoso, la instigación al suicidio y la campaña de odio de Marco Michetti. No puedo entender que algo tan grave no sea tendencia. Usemos Twitter también para lo importante.',
#  'label': 0}

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("sdadas/xlm-roberta-large-twitter")
# Out:
# tokenizer_config.json:   0%|          | 0.00/469 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
def preprocess_function(examples):
    return tokenizer(examples["tweet"], truncation=True)

# %%
tokenized_data = dataset_dict.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/15449 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2727 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
import evaluate

accuracy = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
import numpy as np


def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(
    "sdadas/xlm-roberta-large-twitter", 
    num_labels=4, 
    id2label=id2label, 
    label2id=label2id
)
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]

# %%
training_args = TrainingArguments(
    output_dir="/kaggle/working/sexist_hard1",  # Directory for model outputs
    learning_rate=0.00000527,                  # Learning rate
    per_device_train_batch_size=4,             # Batch size for training
    per_device_eval_batch_size=4,              # Batch size for evaluation
    num_train_epochs=3,                        # Number of training epochs
    weight_decay=0.000636,                     # Weight decay for regularization
    evaluation_strategy="epoch",               # Evaluate at the end of each epoch
    save_strategy="epoch",                     # Save at the end of each epoch
    save_total_limit=1,                        # Only keep the best single model checkpoint
    load_best_model_at_end=True,               # Load the best model at the end of training
    metric_for_best_model='eval_loss',              # Decide the best model based on loss
    push_to_hub=False                          # Do not push to Hugging Face's Model Hub
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["val"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240507_165157-1oy4doqj</code>
# Syncing run <strong><a href='https://wandb.ai/arefinlabibndc19/huggingface/runs/1oy4doqj' target="_blank">fearless-silence-59</a></strong> to <a href='https://wandb.ai/arefinlabibndc19/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/arefinlabibndc19/huggingface' target="_blank">https://wandb.ai/arefinlabibndc19/huggingface</a>
#  View run at <a href='https://wandb.ai/arefinlabibndc19/huggingface/runs/1oy4doqj' target="_blank">https://wandb.ai/arefinlabibndc19/huggingface/runs/1oy4doqj</a>
# {'loss': 1.1131, 'grad_norm': 24.51630973815918, 'learning_rate': 5.042629217361291e-06, 'epoch': 0.13}
# {'loss': 0.7812, 'grad_norm': 39.242801666259766, 'learning_rate': 4.815258434722582e-06, 'epoch': 0.26}
# {'loss': 0.6996, 'grad_norm': 33.833946228027344, 'learning_rate': 4.587887652083873e-06, 'epoch': 0.39}
# {'loss': 0.6294, 'grad_norm': 72.40947723388672, 'learning_rate': 4.360516869445164e-06, 'epoch': 0.52}
# {'loss': 0.5758, 'grad_norm': 125.31611633300781, 'learning_rate': 4.133146086806455e-06, 'epoch': 0.65}
# {'loss': 0.537, 'grad_norm': 3.348951578140259, 'learning_rate': 3.905775304167746e-06, 'epoch': 0.78}
# {'loss': 0.4724, 'grad_norm': 3.873220920562744, 'learning_rate': 3.6784045215290364e-06, 'epoch': 0.91}
# {'eval_loss': 0.45175138115882874, 'eval_accuracy': 0.8892555922258892, 'eval_runtime': 30.2413, 'eval_samples_per_second': 90.175, 'eval_steps_per_second': 22.552, 'epoch': 1.0}
# {'loss': 0.3932, 'grad_norm': 108.73336791992188, 'learning_rate': 3.451033738890327e-06, 'epoch': 1.04}
# {'loss': 0.2906, 'grad_norm': 0.024551399052143097, 'learning_rate': 3.223662956251618e-06, 'epoch': 1.16}
# {'loss': 0.2626, 'grad_norm': 0.47964274883270264, 'learning_rate': 2.996292173612909e-06, 'epoch': 1.29}
# {'loss': 0.2327, 'grad_norm': 29.335861206054688, 'learning_rate': 2.7689213909742e-06, 'epoch': 1.42}
# {'loss': 0.2826, 'grad_norm': 0.02546052075922489, 'learning_rate': 2.5415506083354906e-06, 'epoch': 1.55}
# {'loss': 0.2309, 'grad_norm': 66.78141021728516, 'learning_rate': 2.3141798256967814e-06, 'epoch': 1.68}
# {'loss': 0.2526, 'grad_norm': 46.64540481567383, 'learning_rate': 2.0868090430580725e-06, 'epoch': 1.81}
# {'loss': 0.1883, 'grad_norm': 0.017782462760806084, 'learning_rate': 1.8594382604193633e-06, 'epoch': 1.94}
# {'eval_loss': 0.33455488085746765, 'eval_accuracy': 0.9387605427209388, 'eval_runtime': 30.2216, 'eval_samples_per_second': 90.233, 'eval_steps_per_second': 22.567, 'epoch': 2.0}
# {'loss': 0.1379, 'grad_norm': 31.07646942138672, 'learning_rate': 1.632067477780654e-06, 'epoch': 2.07}
# {'loss': 0.1014, 'grad_norm': 419.664306640625, 'learning_rate': 1.4046966951419452e-06, 'epoch': 2.2}
# {'loss': 0.1364, 'grad_norm': 0.03502613678574562, 'learning_rate': 1.177325912503236e-06, 'epoch': 2.33}
# {'loss': 0.0997, 'grad_norm': 0.016396962106227875, 'learning_rate': 9.499551298645268e-07, 'epoch': 2.46}
# {'loss': 0.1079, 'grad_norm': 0.5726004838943481, 'learning_rate': 7.225843472258175e-07, 'epoch': 2.59}
# {'loss': 0.1062, 'grad_norm': 0.061494436115026474, 'learning_rate': 4.952135645871085e-07, 'epoch': 2.72}
# {'loss': 0.089, 'grad_norm': 0.00653229933232069, 'learning_rate': 2.6784278194839936e-07, 'epoch': 2.85}
# {'loss': 0.1119, 'grad_norm': 0.0066796657629311085, 'learning_rate': 4.0471999309690224e-08, 'epoch': 2.98}
# {'eval_loss': 0.31308209896087646, 'eval_accuracy': 0.9475614228089475, 'eval_runtime': 30.2441, 'eval_samples_per_second': 90.166, 'eval_steps_per_second': 22.55, 'epoch': 3.0}
# {'train_runtime': 2839.3869, 'train_samples_per_second': 16.323, 'train_steps_per_second': 4.082, 'train_loss': 0.3386301543778655, 'epoch': 3.0}
# TrainOutput(global_step=11589, training_loss=0.3386301543778655, metrics={'train_runtime': 2839.3869, 'train_samples_per_second': 16.323, 'train_steps_per_second': 4.082, 'train_loss': 0.3386301543778655, 'epoch': 3.0})

# %%
Train.loc[1650]
# Out:
# tweet    @USER Esos insectos ¿serán las mismísimas "zor...
# label                                                    2
# Name: 1650, dtype: object

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="/kaggle/working/sexist_hard1/checkpoint-11589")

# %%
def infer(txt):
    return classifier(txt)

# %%
for i in range(300, 350):
    txt = Val['tweet'].iloc[i]
    label = id2label[Val['label'].iloc[i]]
    predicted = infer(txt)
    print("id:{}, predicted={}, actual={}".format(i, predicted[0]['label'], label))
# Out:
# id:300, predicted=DIRECT, actual=DIRECT
# id:301, predicted=REPORTED, actual=REPORTED
# id:302, predicted=DIRECT, actual=DIRECT
# id:303, predicted=DIRECT, actual=DIRECT
# id:304, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:305, predicted=DIRECT, actual=DIRECT
# id:306, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:307, predicted=DIRECT, actual=DIRECT
# id:308, predicted=REPORTED, actual=REPORTED
# id:309, predicted=REPORTED, actual=REPORTED
# id:310, predicted=REPORTED, actual=REPORTED
# id:311, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:312, predicted=-, actual=-
# id:313, predicted=-, actual=-
# id:314, predicted=-, actual=-
# id:315, predicted=DIRECT, actual=DIRECT
# id:316, predicted=-, actual=-
# id:317, predicted=-, actual=-
# id:318, predicted=DIRECT, actual=DIRECT
# id:319, predicted=DIRECT, actual=DIRECT
# id:320, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:321, predicted=DIRECT, actual=DIRECT
# id:322, predicted=-, actual=-
# id:323, predicted=-, actual=-
# id:324, predicted=REPORTED, actual=REPORTED
# id:325, predicted=-, actual=-
# id:326, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:327, predicted=-, actual=-
# id:328, predicted=REPORTED, actual=REPORTED
# id:329, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:330, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:331, predicted=DIRECT, actual=DIRECT
# id:332, predicted=DIRECT, actual=DIRECT
# id:333, predicted=DIRECT, actual=DIRECT
# id:334, predicted=REPORTED, actual=REPORTED
# id:335, predicted=DIRECT, actual=DIRECT
# id:336, predicted=REPORTED, actual=REPORTED
# id:337, predicted=DIRECT, actual=DIRECT
# id:338, predicted=REPORTED, actual=REPORTED
# id:339, predicted=REPORTED, actual=REPORTED
# id:340, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:341, predicted=DIRECT, actual=DIRECT
# id:342, predicted=-, actual=JUDGEMENTAL
# id:343, predicted=JUDGEMENTAL, actual=-
# id:344, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:345, predicted=DIRECT, actual=DIRECT
# id:346, predicted=REPORTED, actual=REPORTED
# id:347, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:348, predicted=JUDGEMENTAL, actual=JUDGEMENTAL
# id:349, predicted=REPORTED, actual=REPORTED

# %%
import json

# read JSON file
def read_json(url):
  with open(url) as f:
      data = json.load(f)

  data = [value for key, value in data.items()]
  data = pd.DataFrame(data)
  data["id_EXIST"] = data["id_EXIST"].astype(str)
  # print("read json returns a DATAFRAME")
  return data

# %%
test = read_json('/kaggle/input/existv1/test/EXIST2023_test_clean.json')
test
# Out:
#      id_EXIST lang                                              tweet  \
# 0      500001   es  @Eurogamer_es Todo gamergate desde el desarrol...
# 1      500002   es  @ArCaNgEl__23 @Benzenazi Hombre, no es compara...
# 2      500003   es  yo buscando las empresas metidas en el gamerga...
# 3      500004   es  @jordirico Primero fue internet, luego el game...
# 4      500005   es  @AlonsoQuijano12 Yo estuve metido en el gamerg...
# ...       ...  ...                                                ...
# 2071   600974   en  @AllyMae99 This straight up sounds like “you l...
# 2072   600975   en  Nathaniel is trying to help me with a new fake...
# 2073   600976   en  walkin back from the gym &amp; an older lady s...
# 2074   600977   en  You look like a whore of Babylon bc that’s the...
# 2075   600978   en  @BellaLove823 @lolaoflucia You look like a who...
#
#       number_annotators                                         annotators  \
# 0                     6  [Annotator_810, Annotator_811, Annotator_812, ...
# 1                     6  [Annotator_780, Annotator_816, Annotator_817, ...
# 2                     6  [Annotator_821, Annotator_822, Annotator_823, ...
# 3                     6  [Annotator_827, Annotator_828, Annotator_829, ...
# 4                     6  [Annotator_827, Annotator_828, Annotator_829, ...
# ...                 ...                                                ...
# 2071                  6  [Annotator_942, Annotator_943, Annotator_351, ...
# 2072                  6  [Annotator_997, Annotator_998, Annotator_999, ...
# 2073                  6  [Annotator_997, Annotator_998, Annotator_999, ...
# 2074                  6  [Annotator_1009, Annotator_1010, Annotator_101...
# 2075                  6  [Annotator_1021, Annotator_1022, Annotator_102...
#
#        gender_annotators                          age_annotators  \
# 0     [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 1     [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 2     [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 3     [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 4     [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                  ...                                     ...
# 2071  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 2072  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 2073  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 2074  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 2075  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
#
#                                  ethnicities_annotators  \
# 0     [Hispano or Latino, White or Caucasian, White ...
# 1     [Hispano or Latino, Hispano or Latino, Black o...
# 2     [Hispano or Latino, Hispano or Latino, Asian, ...
# 3     [Hispano or Latino, White or Caucasian, Hispan...
# 4     [Hispano or Latino, White or Caucasian, Hispan...
# ...                                                 ...
# 2071  [Black or African American, White or Caucasian...
# 2072  [Black or African American, White or Caucasian...
# 2073  [Black or African American, White or Caucasian...
# 2074  [White or Caucasian, White or Caucasian, Multi...
# 2075  [White or Caucasian, Hispano or Latino, White ...
#
#                                 study_levels_annotators  \
# 0     [High school degree or equivalent, Master’s de...
# 1     [High school degree or equivalent, Bachelor’s ...
# 2     [Bachelor’s degree, Bachelor’s degree, Master’...
# 3     [High school degree or equivalent, Bachelor’s ...
# 4     [High school degree or equivalent, Bachelor’s ...
# ...                                                 ...
# 2071  [High school degree or equivalent, Master’s de...
# 2072  [High school degree or equivalent, Bachelor’s ...
# 2073  [High school degree or equivalent, Bachelor’s ...
# 2074  [High school degree or equivalent, Bachelor’s ...
# 2075  [Bachelor’s degree, Master’s degree, Bachelor’...
#
#                                    countries_annotators    split
# 0     [Mexico, Spain, Italy, United States, Portugal...  TEST_ES
# 1     [Chile, Mexico, United States, Mexico, Mexico,...  TEST_ES
# 2     [Mexico, Mexico, VietNam, United States, Mexic...  TEST_ES
# 3     [Chile, Spain, Mexico, United Kingdom, Chile, ...  TEST_ES
# 4     [Chile, Spain, Mexico, United Kingdom, Chile, ...  TEST_ES
# ...                                                 ...      ...
# 2071  [South Africa, Spain, Portugal, United States,...  TEST_EN
# 2072  [South Africa, United Kingdom, Australia, Fran...  TEST_EN
# 2073  [South Africa, United Kingdom, Australia, Fran...  TEST_EN
# 2074  [Poland, Portugal, United Kingdom, Greece, Gre...  TEST_EN
# 2075  [Portugal, Mexico, Canada, United Kingdom, Ita...  TEST_EN
#
# [2076 rows x 11 columns]

# %%
test['tweet'] = test['tweet'].apply(simple_preprocess)
test['tweet'] = test['tweet'].apply(tweet_preprocessor_spanish)
test['tweet'] = test['tweet'].apply(tweet_preprocessor_english)

# %%
test['hard'] = test['tweet'].apply(infer)

# %%
test.to_csv("finalhard.csv",index=False)

# %%
from transformers import pipeline

classifiersoft = pipeline("sentiment-analysis", model="/kaggle/working/sexist_hard1/checkpoint-11589", return_all_scores=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
def infersoft(txt):
    # Get predictions for the input text
    results = classifiersoft(txt)
    # Since results is a list of lists of dictionaries, we extract the first element
    return results

# %%
for i in range(300, 350):
    txt = Val['tweet'].iloc[i]
    label = id2label[Val['label'].iloc[i]]
    predicted = infersoft(txt)
    print("id:{}, predicted={}, actual={}".format(i, predicted, label))
# Out:
# id:300, predicted=[[{'label': 'REPORTED', 'score': 4.947224624629598e-06}, {'label': 'JUDGEMENTAL', 'score': 3.968785676988773e-06}, {'label': 'DIRECT', 'score': 0.9998898506164551}, {'label': '-', 'score': 0.00010116654448211193}]], actual=DIRECT
# id:301, predicted=[[{'label': 'REPORTED', 'score': 0.9999741315841675}, {'label': 'JUDGEMENTAL', 'score': 2.726472303038463e-06}, {'label': 'DIRECT', 'score': 1.8457869373378344e-05}, {'label': '-', 'score': 4.6022892092878465e-06}]], actual=REPORTED
# id:302, predicted=[[{'label': 'REPORTED', 'score': 9.892833077174146e-06}, {'label': 'JUDGEMENTAL', 'score': 3.2445561828353675e-06}, {'label': 'DIRECT', 'score': 0.9994915723800659}, {'label': '-', 'score': 0.000495360407512635}]], actual=DIRECT
# id:303, predicted=[[{'label': 'REPORTED', 'score': 4.7783669288037345e-06}, {'label': 'JUDGEMENTAL', 'score': 6.806276815041201e-06}, {'label': 'DIRECT', 'score': 0.9999539852142334}, {'label': '-', 'score': 3.442712113610469e-05}]], actual=DIRECT
# id:304, predicted=[[{'label': 'REPORTED', 'score': 2.00354452317697e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999861717224121}, {'label': 'DIRECT', 'score': 5.951662842562655e-06}, {'label': '-', 'score': 5.8140258261119016e-06}]], actual=JUDGEMENTAL
# id:305, predicted=[[{'label': 'REPORTED', 'score': 1.379667446599342e-05}, {'label': 'JUDGEMENTAL', 'score': 6.06928369961679e-06}, {'label': 'DIRECT', 'score': 0.9994470477104187}, {'label': '-', 'score': 0.0005330464919097722}]], actual=DIRECT
# id:306, predicted=[[{'label': 'REPORTED', 'score': 2.1080761598568643e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999825954437256}, {'label': 'DIRECT', 'score': 7.108334557415219e-06}, {'label': '-', 'score': 8.144073945004493e-06}]], actual=JUDGEMENTAL
# id:307, predicted=[[{'label': 'REPORTED', 'score': 6.198987193783978e-06}, {'label': 'JUDGEMENTAL', 'score': 3.645138576757745e-06}, {'label': 'DIRECT', 'score': 0.9999613761901855}, {'label': '-', 'score': 2.877711085602641e-05}]], actual=DIRECT
# id:308, predicted=[[{'label': 'REPORTED', 'score': 0.999981164932251}, {'label': 'JUDGEMENTAL', 'score': 6.169273092382355e-06}, {'label': 'DIRECT', 'score': 9.922668141371105e-06}, {'label': '-', 'score': 2.792615305224899e-06}]], actual=REPORTED
# id:309, predicted=[[{'label': 'REPORTED', 'score': 0.9999825954437256}, {'label': 'JUDGEMENTAL', 'score': 3.0265989607869415e-06}, {'label': 'DIRECT', 'score': 1.1224991794733796e-05}, {'label': '-', 'score': 3.27176644532301e-06}]], actual=REPORTED
# id:310, predicted=[[{'label': 'REPORTED', 'score': 0.9999786615371704}, {'label': 'JUDGEMENTAL', 'score': 2.4868857053661486e-06}, {'label': 'DIRECT', 'score': 1.3721025425184052e-05}, {'label': '-', 'score': 5.080712980998214e-06}]], actual=REPORTED
# id:311, predicted=[[{'label': 'REPORTED', 'score': 2.261088184241089e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999732971191406}, {'label': 'DIRECT', 'score': 5.4101096793601755e-06}, {'label': '-', 'score': 1.903663360280916e-05}]], actual=JUDGEMENTAL
# id:312, predicted=[[{'label': 'REPORTED', 'score': 1.4530175576510374e-05}, {'label': 'JUDGEMENTAL', 'score': 9.238830898539163e-06}, {'label': 'DIRECT', 'score': 1.711632103251759e-05}, {'label': '-', 'score': 0.9999591112136841}]], actual=-
# id:313, predicted=[[{'label': 'REPORTED', 'score': 0.09764929115772247}, {'label': 'JUDGEMENTAL', 'score': 3.417751213419251e-05}, {'label': 'DIRECT', 'score': 0.0003092255792580545}, {'label': '-', 'score': 0.9020072817802429}]], actual=-
# id:314, predicted=[[{'label': 'REPORTED', 'score': 2.4726481569814496e-05}, {'label': 'JUDGEMENTAL', 'score': 5.7583442867326085e-06}, {'label': 'DIRECT', 'score': 8.229225204559043e-05}, {'label': '-', 'score': 0.999887228012085}]], actual=-
# id:315, predicted=[[{'label': 'REPORTED', 'score': 8.893091944628395e-06}, {'label': 'JUDGEMENTAL', 'score': 2.726669890762423e-06}, {'label': 'DIRECT', 'score': 0.9997729659080505}, {'label': '-', 'score': 0.00021546236530411988}]], actual=DIRECT
# id:316, predicted=[[{'label': 'REPORTED', 'score': 5.256896838545799e-05}, {'label': 'JUDGEMENTAL', 'score': 0.3561096787452698}, {'label': 'DIRECT', 'score': 0.12771698832511902}, {'label': '-', 'score': 0.5161207318305969}]], actual=-
# id:317, predicted=[[{'label': 'REPORTED', 'score': 8.857899047143292e-06}, {'label': 'JUDGEMENTAL', 'score': 1.7922855477081612e-05}, {'label': 'DIRECT', 'score': 0.00012370191689115018}, {'label': '-', 'score': 0.9998494386672974}]], actual=-
# id:318, predicted=[[{'label': 'REPORTED', 'score': 6.079224476707168e-06}, {'label': 'JUDGEMENTAL', 'score': 4.739393261843361e-06}, {'label': 'DIRECT', 'score': 0.9997406601905823}, {'label': '-', 'score': 0.00024845567531883717}]], actual=DIRECT
# id:319, predicted=[[{'label': 'REPORTED', 'score': 7.894767804828007e-06}, {'label': 'JUDGEMENTAL', 'score': 2.570014430602896e-06}, {'label': 'DIRECT', 'score': 0.9999371767044067}, {'label': '-', 'score': 5.231409159023315e-05}]], actual=DIRECT
# id:320, predicted=[[{'label': 'REPORTED', 'score': 2.1315640879038256e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999849796295166}, {'label': 'DIRECT', 'score': 7.1206932261702605e-06}, {'label': '-', 'score': 5.758385668741539e-06}]], actual=JUDGEMENTAL
# id:321, predicted=[[{'label': 'REPORTED', 'score': 7.92027003626572e-06}, {'label': 'JUDGEMENTAL', 'score': 2.955797981485375e-06}, {'label': 'DIRECT', 'score': 0.9999608993530273}, {'label': '-', 'score': 2.822612259478774e-05}]], actual=DIRECT
# id:322, predicted=[[{'label': 'REPORTED', 'score': 1.7461705283494666e-05}, {'label': 'JUDGEMENTAL', 'score': 7.701031790929846e-06}, {'label': 'DIRECT', 'score': 0.00044942920794710517}, {'label': '-', 'score': 0.9995254278182983}]], actual=-
# id:323, predicted=[[{'label': 'REPORTED', 'score': 7.6109122346679214e-06}, {'label': 'JUDGEMENTAL', 'score': 2.3807464458514005e-05}, {'label': 'DIRECT', 'score': 2.7470465283840895e-05}, {'label': '-', 'score': 0.9999411106109619}]], actual=-
# id:324, predicted=[[{'label': 'REPORTED', 'score': 0.9999819993972778}, {'label': 'JUDGEMENTAL', 'score': 3.1938716347212903e-06}, {'label': 'DIRECT', 'score': 1.0145244232262485e-05}, {'label': '-', 'score': 4.662788342102431e-06}]], actual=REPORTED
# id:325, predicted=[[{'label': 'REPORTED', 'score': 6.815065717091784e-06}, {'label': 'JUDGEMENTAL', 'score': 1.0388603186584078e-05}, {'label': 'DIRECT', 'score': 4.67873178422451e-05}, {'label': '-', 'score': 0.9999359846115112}]], actual=-
# id:326, predicted=[[{'label': 'REPORTED', 'score': 1.6722525515433517e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999839067459106}, {'label': 'DIRECT', 'score': 5.754332505603088e-06}, {'label': '-', 'score': 8.646065907669254e-06}]], actual=JUDGEMENTAL
# id:327, predicted=[[{'label': 'REPORTED', 'score': 1.5846051610424183e-05}, {'label': 'JUDGEMENTAL', 'score': 8.95079028850887e-06}, {'label': 'DIRECT', 'score': 3.517149161780253e-05}, {'label': '-', 'score': 0.999940037727356}]], actual=-
# id:328, predicted=[[{'label': 'REPORTED', 'score': 0.9999786615371704}, {'label': 'JUDGEMENTAL', 'score': 3.7523072933254298e-06}, {'label': 'DIRECT', 'score': 1.4561157513526268e-05}, {'label': '-', 'score': 3.1264457902580034e-06}]], actual=REPORTED
# id:329, predicted=[[{'label': 'REPORTED', 'score': 2.4334362933586817e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999850988388062}, {'label': 'DIRECT', 'score': 6.676742941635894e-06}, {'label': '-', 'score': 5.806367425975623e-06}]], actual=JUDGEMENTAL
# id:330, predicted=[[{'label': 'REPORTED', 'score': 1.949726311067934e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999759197235107}, {'label': 'DIRECT', 'score': 6.677406872768188e-06}, {'label': '-', 'score': 1.5528043149970472e-05}]], actual=JUDGEMENTAL
# id:331, predicted=[[{'label': 'REPORTED', 'score': 7.99126792117022e-06}, {'label': 'JUDGEMENTAL', 'score': 2.4802582174743293e-06}, {'label': 'DIRECT', 'score': 0.9999032020568848}, {'label': '-', 'score': 8.628092473372817e-05}]], actual=DIRECT
# id:332, predicted=[[{'label': 'REPORTED', 'score': 7.507541340601165e-06}, {'label': 'JUDGEMENTAL', 'score': 3.1757267606735695e-06}, {'label': 'DIRECT', 'score': 0.9999570846557617}, {'label': '-', 'score': 3.213674790458754e-05}]], actual=DIRECT
# id:333, predicted=[[{'label': 'REPORTED', 'score': 7.93870731286006e-06}, {'label': 'JUDGEMENTAL', 'score': 3.2665634535078425e-06}, {'label': 'DIRECT', 'score': 0.9999103546142578}, {'label': '-', 'score': 7.840829493943602e-05}]], actual=DIRECT
# id:334, predicted=[[{'label': 'REPORTED', 'score': 0.9999761581420898}, {'label': 'JUDGEMENTAL', 'score': 4.329132025304716e-06}, {'label': 'DIRECT', 'score': 1.5015147255326156e-05}, {'label': '-', 'score': 4.561169134831289e-06}]], actual=REPORTED
# id:335, predicted=[[{'label': 'REPORTED', 'score': 5.8756882026500534e-06}, {'label': 'JUDGEMENTAL', 'score': 4.295151484257076e-06}, {'label': 'DIRECT', 'score': 0.9999607801437378}, {'label': '-', 'score': 2.904032589867711e-05}]], actual=DIRECT
# id:336, predicted=[[{'label': 'REPORTED', 'score': 0.9999724626541138}, {'label': 'JUDGEMENTAL', 'score': 1.065383548848331e-05}, {'label': 'DIRECT', 'score': 1.0252096217300277e-05}, {'label': '-', 'score': 6.6202924244862515e-06}]], actual=REPORTED
# id:337, predicted=[[{'label': 'REPORTED', 'score': 9.071051863429602e-06}, {'label': 'JUDGEMENTAL', 'score': 4.0874815567804035e-06}, {'label': 'DIRECT', 'score': 0.9996823072433472}, {'label': '-', 'score': 0.0003046029305551201}]], actual=DIRECT
# id:338, predicted=[[{'label': 'REPORTED', 'score': 0.9999793767929077}, {'label': 'JUDGEMENTAL', 'score': 3.4313347896386404e-06}, {'label': 'DIRECT', 'score': 1.4027666111360304e-05}, {'label': '-', 'score': 3.144703896396095e-06}]], actual=REPORTED
# id:339, predicted=[[{'label': 'REPORTED', 'score': 0.9999786615371704}, {'label': 'JUDGEMENTAL', 'score': 3.5303189633850707e-06}, {'label': 'DIRECT', 'score': 1.4001499039295595e-05}, {'label': '-', 'score': 3.8305283851514105e-06}]], actual=REPORTED
# id:340, predicted=[[{'label': 'REPORTED', 'score': 4.213386546325637e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999734163284302}, {'label': 'DIRECT', 'score': 4.131312380195595e-06}, {'label': '-', 'score': 1.821774640120566e-05}]], actual=JUDGEMENTAL
# id:341, predicted=[[{'label': 'REPORTED', 'score': 6.1571454352815636e-06}, {'label': 'JUDGEMENTAL', 'score': 3.843695139948977e-06}, {'label': 'DIRECT', 'score': 0.9999407529830933}, {'label': '-', 'score': 4.919925777358003e-05}]], actual=DIRECT
# id:342, predicted=[[{'label': 'REPORTED', 'score': 1.7348122128169052e-05}, {'label': 'JUDGEMENTAL', 'score': 0.0010683313012123108}, {'label': 'DIRECT', 'score': 8.633794641355053e-05}, {'label': '-', 'score': 0.9988279938697815}]], actual=JUDGEMENTAL
# id:343, predicted=[[{'label': 'REPORTED', 'score': 3.903641481883824e-05}, {'label': 'JUDGEMENTAL', 'score': 0.8469721674919128}, {'label': 'DIRECT', 'score': 0.15077966451644897}, {'label': '-', 'score': 0.0022090752609074116}]], actual=-
# id:344, predicted=[[{'label': 'REPORTED', 'score': 2.034039653153741e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999858140945435}, {'label': 'DIRECT', 'score': 4.976807758794166e-06}, {'label': '-', 'score': 7.128166544134729e-06}]], actual=JUDGEMENTAL
# id:345, predicted=[[{'label': 'REPORTED', 'score': 8.137290024023969e-06}, {'label': 'JUDGEMENTAL', 'score': 2.1214011667325394e-06}, {'label': 'DIRECT', 'score': 0.9998835325241089}, {'label': '-', 'score': 0.0001062187147908844}]], actual=DIRECT
# id:346, predicted=[[{'label': 'REPORTED', 'score': 0.9999790191650391}, {'label': 'JUDGEMENTAL', 'score': 3.846072559099412e-06}, {'label': 'DIRECT', 'score': 1.2378078281471971e-05}, {'label': '-', 'score': 4.750900643557543e-06}]], actual=REPORTED
# id:347, predicted=[[{'label': 'REPORTED', 'score': 2.8676274723693496e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999868869781494}, {'label': 'DIRECT', 'score': 5.620306183118373e-06}, {'label': '-', 'score': 4.619162609742489e-06}]], actual=JUDGEMENTAL
# id:348, predicted=[[{'label': 'REPORTED', 'score': 2.994664100697264e-06}, {'label': 'JUDGEMENTAL', 'score': 0.9999856948852539}, {'label': 'DIRECT', 'score': 4.508790425461484e-06}, {'label': '-', 'score': 6.739434411429102e-06}]], actual=JUDGEMENTAL
# id:349, predicted=[[{'label': 'REPORTED', 'score': 0.9999781847000122}, {'label': 'JUDGEMENTAL', 'score': 8.465892278763931e-06}, {'label': 'DIRECT', 'score': 7.356556579907192e-06}, {'label': '-', 'score': 5.999828317726497e-06}]], actual=REPORTED

# %%
test['soft'] = test['tweet'].apply(infersoft)

# %%
test['soft'].iloc[0]
# Out:
# [[{'label': 'REPORTED', 'score': 8.335934580827598e-06},
#   {'label': 'JUDGEMENTAL', 'score': 1.4897758774168324e-05},
#   {'label': 'DIRECT', 'score': 3.2016891054809093e-05},
#   {'label': '-', 'score': 0.9999446868896484}]]

# %%
test.iloc[0]
# Out:
# id_EXIST                                                              500001
# lang                                                                      es
# tweet                      @USER Todo gamergate desde el desarrollo hasta...
# number_annotators                                                          6
# annotators                 [Annotator_810, Annotator_811, Annotator_812, ...
# gender_annotators                                         [F, F, F, M, M, M]
# age_annotators                        [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ethnicities_annotators     [Hispano or Latino, White or Caucasian, White ...
# study_levels_annotators    [High school degree or equivalent, Master’s de...
# countries_annotators       [Mexico, Spain, Italy, United States, Portugal...
# split                                                                TEST_ES
# hard                           [{'label': '-', 'score': 0.9999446868896484}]
# soft                       [[{'label': 'REPORTED', 'score': 8.33593458082...
# Name: 0, dtype: object

# %%
def convert_label(hard_values):
    label = hard_values[0]['label']  # Assuming there's always at least one result in 'hard'
    if label == '-':
        return 'NO'
    return label

# %%
test['value'] = test['hard'].apply(convert_label)

# Create the 'test_case' column
test['test_case'] = 'EXIST2024'

# Select and rename the necessary columns to create the final DataFrame
# Ensure you use the column name as a string and rename using the correct syntax.
final_df = test[['id_EXIST', 'value', 'test_case']].rename(columns={'id_EXIST': 'id'})

# Convert the DataFrame into a list of dictionaries
result_dicts = final_df.to_dict(orient='records')

final_df
# Out:
#           id        value  test_case
# 0     500001           NO  EXIST2024
# 1     500002           NO  EXIST2024
# 2     500003           NO  EXIST2024
# 3     500004  JUDGEMENTAL  EXIST2024
# 4     500005           NO  EXIST2024
# ...      ...          ...        ...
# 2071  600974       DIRECT  EXIST2024
# 2072  600975     REPORTED  EXIST2024
# 2073  600976     REPORTED  EXIST2024
# 2074  600977       DIRECT  EXIST2024
# 2075  600978       DIRECT  EXIST2024
#
# [2076 rows x 3 columns]

# %%
import json

# Assuming 'result_dicts' is your list of dictionaries
# Define the path to the output JSON file
file_path = '/kaggle/working/task2_hard_UNED_1.json'

# Open the file in write mode and use json.dump() to write the list of dictionaries
with open(file_path, 'w') as file:
    json.dump(result_dicts, file, indent=4)  # The 'indent' parameter is optional but helps with readability

print(f"Data saved to {file_path}")
# Out:
# Data saved to /kaggle/working/task2_hard_UNED_1.json

# %%
def process_soft_entry(soft_values, id_value):
    value_dict = {}
    # Establish a template for the order and labels we expect
    template = {'NO': None, 'DIRECT': None, 'REPORTED': None, 'JUDGEMENTAL': None}

    for item in soft_values[0]:  # Access the first element since it's a nested list
        label = 'NO' if item['label'] == '-' else item['label']
        # Use formatted strings to avoid scientific notation and maintain high precision
        formatted_score = f"{item['score']:.20f}"
        # Remove trailing zeros and the unneeded decimal point if it's a whole number
        value_dict[label] = formatted_score.rstrip('0').rstrip('.')

    # Merge the dictionary while maintaining order and replacing None with actual values
    for key in template:
        if key in value_dict:
            template[key] = float(value_dict[key])
    
    return {
        "id": id_value,
        "value": template,
        "test_case": "EXIST2024"
    }

# %%
# Apply the function to each row in the DataFrame
result_dicts = test.apply(lambda row: process_soft_entry(row['soft'], row['id_EXIST']), axis=1)

# Convert the resulting Series of dictionaries to a list
result_list = result_dicts.tolist()

# Optionally, convert this list to a JSON file
file_path = '/kaggle/working/task2_soft_UNED_3.json'
with open(file_path, 'w') as file:
    json.dump(result_list, file, indent=4)

print(f"Data saved to {file_path}")
# Out:
# Data saved to /kaggle/working/task2_soft_UNED_3.json

# %%
def processsoft(soft_values):
    updated_entries = []
    for entry in soft_values[0]:  # Access the first element since it's a nested list
        label = 'NO' if entry['label'] == '-' else entry['label']
        # Format the score to avoid scientific notation and ensure full decimal expansion
        formatted_score = format(entry['score'], '.20f').rstrip('0').rstrip('.')
        if formatted_score == '':
            formatted_score = '0'  # Handling very small numbers formatted to '0.'
        # Append the updated dictionary to the list
        updated_entries.append({
            'label': label,
            'score': float(formatted_score) if formatted_score != '0' else 0.0
        })
    return [updated_entries]

# Apply the function to each 'soft' entry
test['soft'] = test['soft'].apply(processsoft)

# Now, let's print the first entry to see the changes
print(test['soft'].iloc[0])
# Out:
# [[{'label': 'REPORTED', 'score': 8.3359345808276e-06}, {'label': 'JUDGEMENTAL', 'score': 1.489775877416832e-05}, {'label': 'DIRECT', 'score': 3.201689105480909e-05}, {'label': 'NO', 'score': 0.9999446868896484}]]

# %%
test['soft'].iloc[0]
# Out:
# [[{'label': 'REPORTED', 'score': 8.335934580827598e-06},
#   {'label': 'JUDGEMENTAL', 'score': 1.4897758774168324e-05},
#   {'label': 'DIRECT', 'score': 3.2016891054809093e-05},
#   {'label': '-', 'score': 0.9999446868896484}]]
